# %%
from fastai import *
from fastai.vision import *
from pathlib import Path

from fastai_autoencoder.bottleneck import VAEBottleneck
from fastai_autoencoder.callback import VAEHook, HighFrequencyLoss
from fastai_autoencoder.util import *
from fastai_autoencoder.vision.learn import VisionAELearner
from mnist_model import create_decoder, create_encoder_denseblock

# %%
def get_data(train_size,bs = 64,size = 28,gray = True):

    path = untar_data(URLs.MNIST)
    tfms = get_transforms(do_flip = False)

    data = (ImageList.from_folder(path/"training")
            .split_none()
            .label_from_folder()
            .transform(tfms,size = size)
            .databunch(bs = bs))

    # Creation of a small dataset of all images
    n = len(data.train_ds.x.items)

    train_idx = np.random.choice(n,train_size,replace = False)
    x_train,y_train = data.train_ds.x.items[train_idx],data.train_ds.y.items[train_idx]
    train_df = pd.DataFrame({"name":x_train,"label":y_train})
    
    valid_idx = np.array(list(set(np.arange(n)) - set(train_idx)))
    x_valid,y_valid = data.train_ds.x.items[valid_idx],data.train_ds.y.items[valid_idx]
    valid_df = pd.DataFrame({"name" : x_valid,"label":y_valid})

    path = Path("/")

    # Data used ofr the training of the autoencoder
    data = (ImageList.from_df(train_df,path)
            .split_by_rand_pct(seed=42)
            .label_from_df()
            .transform(tfms,size = size)
            .databunch(bs = bs))
    
    valid_data = (ImageList.from_df(valid_df,path)
            .split_none()
            .label_from_df()
            .transform(tfms,size = size)
            .databunch(bs = bs))
    
    def get_one_channel(batch):
        x,y = batch
        return x[:,0,:,:].unsqueeze(1),y
    get_one_channel._order = 99
    
    if gray:
        data.add_tfm(get_one_channel)
        valid_data.add_tfm(get_one_channel)
    
    return data, valid_data

# %%
import neptune
from neptunecontrib.monitoring.fastai import NeptuneMonitor

neptune.init('danywin/fastai-autoencoder-mnist')
# Out:
# Project(danywin/fastai-autoencoder-mnist)

# %%
def params_to_str(d) : return {k:str(v) for k,v in d.items()}

PARAMS = {
    "data":"MNIST",
    "train_size" : 512,
    "size":28,
    "bs":128,
    
    "conv":nn.Conv2d,
    "act_fn":nn.ReLU,
    "bn":nn.BatchNorm2d,
    "rec_loss":"mse",
    
    "enc_fn" : create_encoder_denseblock,
    "enc_args": {
        "n_dense":3,
        "c_start" :4
    },
    "bn_fn": VAEBottleneck,
    "bn_args" : {
        "nfs":[128,24]
    },
    "dec_fn":create_decoder,
    "dec_args" : {
        "nfs":[24,64,32,16,8,4,2,1],
        "ks":[3,1,3,1,3,1],   
        "size": 28
    },
    
    "beta_kl":1,
    "hf_loss_args" : {
        "threshold":1e-3,
        "scaling":True,
        "mul":0
    },
    
    "n_epochs":[500,500],
    "lrs" : [1e-2,1e-2 /2]
}

# %%
train_size = PARAMS["train_size"]
bs = PARAMS["bs"]
size = PARAMS["size"]

train_size = int(train_size * 1.25)

data, valid_data = get_data(train_size,bs=bs,size=size)

# %%
path = untar_data(URLs.MNIST_TINY)
tfms = get_transforms(do_flip = False)

data = (ImageList.from_folder(path)
        .split_by_rand_pct(seed=42)
        .label_from_folder()
        .transform(tfms,size = size)
        .databunch(bs = bs))

def get_one_channel(batch):
    x,y = batch
    return x[:,0,:,:].unsqueeze(1),y

get_one_channel._order = 99

data.add_tfm(get_one_channel)

# %%
conv = PARAMS["conv"]
act_fn = PARAMS["act_fn"]
bn = PARAMS["bn"]
rec_loss = PARAMS["rec_loss"]

enc_fn = PARAMS["enc_fn"]
enc_args = PARAMS["enc_args"]
enc = enc_fn(**enc_args)

bn_fn = PARAMS["bn_fn"]
bn_args = PARAMS["bn_args"]
bn = bn_fn(**bn_args)

dec_fn = PARAMS["dec_fn"]
dec_args = PARAMS["dec_args"]
dec = dec_fn(**dec_args)

learn = VisionAELearner(data,rec_loss,enc,bn,dec)
kl_hook = VAEHook(learn,beta=PARAMS["beta_kl"])
hf_loss = HighFrequencyLoss(learn,**PARAMS["hf_loss_args"])

dec_modules = list(learn.dec[1].children())
learn.set_dec_modules(dec_modules)

# %%
x,y = data.one_batch()

# %%
experiment = {
    "name":"vae_experiment threshold 1e-2",
    "description":"Using scale factor on Spatial Decoder",
    "params":params_to_str(PARAMS),
    "tags" : ["mnist","vae"],
    "upload_source_files":["mnist_model.py"]
}

with neptune.create_experiment(**experiment) as exp:
    
    name = experiment['name']
    cbs = [hf_loss,NeptuneMonitor()]
    
    for i,(n_epoch,lr) in enumerate(zip(PARAMS["n_epochs"],PARAMS["lrs"])):
        # First we train the VAE 
        if i == 0:
            # Without KL divergence first
            learn.fit_one_cycle(n_epoch,lr,callbacks=cbs)
        else: 
            # With KL then
            cbs += [kl_hook]
            learn.fit_one_cycle(n_epoch,lr,callbacks=cbs)
        
        fig = learn.plot_rec_steps(x,return_fig=True)
        fig_name = f"Reconstructions.png"
        fig.savefig(fig_name) 
        exp.send_image(fig_name,fig_name)
        
        fig = learn.plot_2d_latents(DatasetType.Train,return_fig=True)
        fig_name = f"T-SNE in 2D.png"
        fig.savefig(fig_name) 
        exp.send_image(fig_name,fig_name)
    
    # We save the model 
    torch.save(learn.model.state_dict(),"model.pth")
    exp.send_artifact('model.pth')
# Out:
# Computing the TSNE projection

# %%
learn.plot_2d_latents(DatasetType.Train)
# Out:
# Computing the TSNE projection

# %%
learn.path = Path()
learn.load("model_mnist_512")
# Out:
# VisionAELearner(data=ImageDataBunch;
#
# Train: LabelList (512 items)
# x: ImageList
# Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28)
# y: CategoryList
# 4,9,1,5,0
# Path: /;
#
# Valid: LabelList (128 items)
# x: ImageList
# Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28)
# y: CategoryList
# 8,6,9,7,1
# Path: /;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (0): ConvBnRelu(
#         (conv): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (1): ResBlock(
#         (conv1): ConvBnRelu(
#           (conv): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (conv2): ConvBnRelu(
#           (conv): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (2): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#     (1): Sequential(
#       (0): DenseBlock(
#         (conv): ResBlock(
#           (conv1): ConvBnRelu(
#             (conv): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#           (conv2): ConvBnRelu(
#             (conv): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#         )
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#     (2): Sequential(
#       (0): DenseBlock(
#         (conv): ResBlock(
#           (conv1): ConvBnRelu(
#             (conv): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#           (conv2): ConvBnRelu(
#             (conv): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#         )
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#     (3): Sequential(
#       (0): DenseBlock(
#         (conv): ResBlock(
#           (conv1): ConvBnRelu(
#             (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#           (conv2): ConvBnRelu(
#             (conv): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#         )
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#   )
#   (1): VAEBottleneck(
#     (fc): Sequential(
#       (0): VAELayer(
#         (blinear): VAELinear(
#           (linear): Linear(in_features=128, out_features=24, bias=True)
#           (mu_linear): Linear(in_features=24, out_features=24, bias=True)
#           (logvar_linear): Linear(in_features=24, out_features=24, bias=True)
#         )
#         (sampler): NormalSampler()
#       )
#     )
#   )
#   (2): Sequential(
#     (0): SpatialDecoder2D()
#     (1): Sequential(
#       (0): ConvBnRelu(
#         (conv): PointwiseConv(
#           (conv): Conv2d(26, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (1): ConvBnRelu(
#         (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (2): ConvBnRelu(
#         (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (3): ConvBnRelu(
#         (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (4): ConvBnRelu(
#         (conv): Conv2d(8, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (5): ConvBnRelu(
#         (conv): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (6): ConvBnRelu(
#         (conv): Conv2d(2, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=<bound method AutoEncoderLearner.loss_func of ...>, metrics=[], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[ReplaceTargetCallback
# learn: ...], layer_groups=[Sequential(
#   (0): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace)
#   (3): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU(inplace)
#   (6): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (7): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU(inplace)
#   (9): ReflectionPad2d([1, 1, 1, 1])
#   (10): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (11): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU(inplace)
#   (13): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (14): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (15): ReLU(inplace)
#   (16): ReflectionPad2d([1, 1, 1, 1])
#   (17): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (18): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): ReLU(inplace)
#   (20): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (21): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): ReLU(inplace)
#   (23): ReflectionPad2d([1, 1, 1, 1])
#   (24): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (25): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): ReLU(inplace)
#   (27): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (28): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (29): ReLU(inplace)
#   (30): ReflectionPad2d([1, 1, 1, 1])
#   (31): Linear(in_features=128, out_features=24, bias=True)
#   (32): Linear(in_features=24, out_features=24, bias=True)
#   (33): Linear(in_features=24, out_features=24, bias=True)
#   (34): NormalSampler()
#   (35): SpatialDecoder2D()
#   (36): Conv2d(26, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (37): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (38): ReLU(inplace)
#   (39): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (40): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (41): ReLU(inplace)
#   (42): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (43): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (44): ReLU(inplace)
#   (45): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (46): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (47): ReLU(inplace)
#   (48): Conv2d(8, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (49): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (50): ReLU(inplace)
#   (51): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (52): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (53): ReLU(inplace)
#   (54): Conv2d(2, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (55): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (56): ReLU(inplace)
# )], add_time=True, silent=False)

# %%
learn.plot_rec_steps(x)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
learn.path = Path()
learn.save("model_mnist_tiny")

# %%
learn.plot_2d_latents(DatasetType.Train)
# Out:
# Computing the TSNE projection

# %%
data,valid_data = get_data(512,gray=False)
clf = cnn_learner(data, models.resnet18, metrics=accuracy)

# %%
clf.path = Path()
clf.lr_find()
clf.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
clf.fit_one_cycle(125,1e-1/2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.271539</td>
#       <td>2.154356</td>
#       <td>0.186275</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.019575</td>
#       <td>2.111876</td>
#       <td>0.156863</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.843136</td>
#       <td>1.772117</td>
#       <td>0.303922</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.698118</td>
#       <td>1.437365</td>
#       <td>0.480392</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.543757</td>
#       <td>1.261609</td>
#       <td>0.578431</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.431031</td>
#       <td>1.289202</td>
#       <td>0.539216</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.348677</td>
#       <td>0.994201</td>
#       <td>0.617647</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.248523</td>
#       <td>0.816133</td>
#       <td>0.715686</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.181667</td>
#       <td>0.761964</td>
#       <td>0.715686</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.102507</td>
#       <td>0.789999</td>
#       <td>0.725490</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.032635</td>
#       <td>0.810460</td>
#       <td>0.705882</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.971190</td>
#       <td>0.765209</td>
#       <td>0.725490</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.929624</td>
#       <td>0.960038</td>
#       <td>0.725490</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.890026</td>
#       <td>0.800644</td>
#       <td>0.774510</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.853169</td>
#       <td>0.908254</td>
#       <td>0.705882</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.832926</td>
#       <td>0.756717</td>
#       <td>0.705882</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.802914</td>
#       <td>0.833103</td>
#       <td>0.754902</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.780619</td>
#       <td>1.207845</td>
#       <td>0.696078</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.764215</td>
#       <td>0.996636</td>
#       <td>0.735294</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.768698</td>
#       <td>1.156481</td>
#       <td>0.764706</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.811397</td>
#       <td>2.643066</td>
#       <td>0.627451</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.846163</td>
#       <td>2.235020</td>
#       <td>0.598039</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.854872</td>
#       <td>1.724978</td>
#       <td>0.647059</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.847690</td>
#       <td>1.248196</td>
#       <td>0.705882</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.850039</td>
#       <td>1.501101</td>
#       <td>0.637255</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.840446</td>
#       <td>1.155319</td>
#       <td>0.705882</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.828819</td>
#       <td>0.955189</td>
#       <td>0.735294</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.811790</td>
#       <td>1.235140</td>
#       <td>0.735294</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.783679</td>
#       <td>0.848375</td>
#       <td>0.754902</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.774931</td>
#       <td>0.956240</td>
#       <td>0.735294</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.777146</td>
#       <td>0.938709</td>
#       <td>0.735294</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.780849</td>
#       <td>1.231207</td>
#       <td>0.705882</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.806360</td>
#       <td>2.075348</td>
#       <td>0.568627</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.796992</td>
#       <td>0.793153</td>
#       <td>0.784314</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.791108</td>
#       <td>1.329215</td>
#       <td>0.676471</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.791062</td>
#       <td>1.284262</td>
#       <td>0.656863</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.798749</td>
#       <td>0.980937</td>
#       <td>0.754902</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.784835</td>
#       <td>0.852927</td>
#       <td>0.764706</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.783743</td>
#       <td>1.216984</td>
#       <td>0.735294</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.795622</td>
#       <td>0.905425</td>
#       <td>0.803922</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.776488</td>
#       <td>1.980500</td>
#       <td>0.568627</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.767640</td>
#       <td>0.808504</td>
#       <td>0.735294</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.776348</td>
#       <td>0.992724</td>
#       <td>0.735294</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.799655</td>
#       <td>1.114266</td>
#       <td>0.735294</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.792334</td>
#       <td>1.012545</td>
#       <td>0.715686</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.790123</td>
#       <td>1.436027</td>
#       <td>0.715686</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.781067</td>
#       <td>0.902309</td>
#       <td>0.754902</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.768909</td>
#       <td>0.841047</td>
#       <td>0.784314</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.745250</td>
#       <td>0.854825</td>
#       <td>0.754902</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.724025</td>
#       <td>1.177624</td>
#       <td>0.725490</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.699649</td>
#       <td>1.375844</td>
#       <td>0.686275</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.695589</td>
#       <td>2.077906</td>
#       <td>0.588235</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.695535</td>
#       <td>0.871073</td>
#       <td>0.705882</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.670519</td>
#       <td>1.716764</td>
#       <td>0.568627</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.658157</td>
#       <td>0.488640</td>
#       <td>0.813725</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.642960</td>
#       <td>0.578480</td>
#       <td>0.813725</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.665087</td>
#       <td>0.960805</td>
#       <td>0.764706</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.661164</td>
#       <td>0.879750</td>
#       <td>0.764706</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.646717</td>
#       <td>0.956401</td>
#       <td>0.754902</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.641241</td>
#       <td>0.912968</td>
#       <td>0.754902</td>
#       <td>0

# %%
lin = nn.Sequential(nn.Linear(64,10))
layers = [learn.encode,lin]
clf_model = nn.Sequential(*layers)

clf = Learner(learn.data,clf_model,metrics=accuracy,layer_groups=layers)
lr = 1e-2

# %%
plt.imshow(x[0][0],cmap="gray")

# %%
plt.imshow(img_back[0],cmap="gray")

# %%
fig,ax = plt.subplots(2,figsize=(16,16))
ax[0].imshow(x[i][0],cmap="gray")
x.squeeze(1).numpy()[idx] = 0

ax[1].imshow(x[i][0],cmap="gray")

# %%
img_back.shape
# Out:
# (64, 28, 28)

# %%
idx = np.isclose(img_back,0,atol=1e-3)
plt.imshow(img_back[2],cmap="gray")

# %%
img = x[2]
img = img.reshape(28,28)


f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

rows, cols = img.shape
crow,ccol = rows//2 , cols//2
fshift[crow-window_size:crow+window_size, ccol-window_size:ccol+window_size] = 0
f_ishift = np.fft.ifftshift(fshift)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)
img_back = img_back / img_back.sum()

plt.subplot(131),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(img_back, cmap = 'gray')
plt.title('Image after HPF'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(img_back)
plt.title('Result in JET'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
data, valid_data = get_data(640)
learn.data = data

# %%
learn.plot_2d_latents(DatasetType.Train)
# Out:
# Computing the TSNE projection

# %%
data, valid_data = get_data(160)

# %%
learn.load("model_mnist_tiny")
# Out:
# VisionAELearner(data=ImageDataBunch;
#
# Train: LabelList (410 items)
# x: ImageList
# Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28)
# y: CategoryList
# 7,6,2,9,6
# Path: /;
#
# Valid: LabelList (102 items)
# x: ImageList
# Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28)
# y: CategoryList
# 0,8,7,6,5
# Path: /;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (0): ConvBnRelu(
#         (conv): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (1): ResBlock(
#         (conv1): ConvBnRelu(
#           (conv): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (conv2): ConvBnRelu(
#           (conv): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (2): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#     (1): Sequential(
#       (0): DenseBlock(
#         (conv): ResBlock(
#           (conv1): ConvBnRelu(
#             (conv): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#           (conv2): ConvBnRelu(
#             (conv): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#         )
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#     (2): Sequential(
#       (0): DenseBlock(
#         (conv): ResBlock(
#           (conv1): ConvBnRelu(
#             (conv): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#           (conv2): ConvBnRelu(
#             (conv): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#         )
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#     (3): Sequential(
#       (0): DenseBlock(
#         (conv): ResBlock(
#           (conv1): ConvBnRelu(
#             (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#           (conv2): ConvBnRelu(
#             (conv): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#         )
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#   )
#   (1): VAEBottleneck(
#     (fc): Sequential(
#       (0): VAELayer(
#         (blinear): VAELinear(
#           (linear): Linear(in_features=128, out_features=24, bias=True)
#           (mu_linear): Linear(in_features=24, out_features=24, bias=True)
#           (logvar_linear): Linear(in_features=24, out_features=24, bias=True)
#         )
#         (sampler): NormalSampler()
#       )
#     )
#   )
#   (2): Sequential(
#     (0): SpatialDecoder2D()
#     (1): Sequential(
#       (0): ConvBnRelu(
#         (conv): PointwiseConv(
#           (conv): Conv2d(26, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (1): ConvBnRelu(
#         (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (2): ConvBnRelu(
#         (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (3): ConvBnRelu(
#         (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (4): ConvBnRelu(
#         (conv): Conv2d(8, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (5): ConvBnRelu(
#         (conv): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (6): ConvBnRelu(
#         (conv): Conv2d(2, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=<bound method AutoEncoderLearner.loss_func of ...>, metrics=[], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[ReplaceTargetCallback
# learn: ...], layer_groups=[Sequential(
#   (0): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace)
#   (3): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU(inplace)
#   (6): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (7): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU(inplace)
#   (9): ReflectionPad2d([1, 1, 1, 1])
#   (10): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (11): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU(inplace)
#   (13): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (14): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (15): ReLU(inplace)
#   (16): ReflectionPad2d([1, 1, 1, 1])
#   (17): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (18): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): ReLU(inplace)
#   (20): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (21): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): ReLU(inplace)
#   (23): ReflectionPad2d([1, 1, 1, 1])
#   (24): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (25): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): ReLU(inplace)
#   (27): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (28): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (29): ReLU(inplace)
#   (30): ReflectionPad2d([1, 1, 1, 1])
#   (31): Linear(in_features=128, out_features=24, bias=True)
#   (32): Linear(in_features=24, out_features=24, bias=True)
#   (33): Linear(in_features=24, out_features=24, bias=True)
#   (34): NormalSampler()
#   (35): SpatialDecoder2D()
#   (36): Conv2d(26, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (37): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (38): ReLU(inplace)
#   (39): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (40): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (41): ReLU(inplace)
#   (42): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (43): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (44): ReLU(inplace)
#   (45): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (46): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (47): ReLU(inplace)
#   (48): Conv2d(8, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (49): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (50): ReLU(inplace)
#   (51): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (52): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (53): ReLU(inplace)
#   (54): Conv2d(2, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (55): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (56): ReLU(inplace)
# )], add_time=True, silent=False)

# %%
# learn.load("model_mnist_512")

lin = nn.Sequential(nn.Linear(24,17),nn.BatchNorm1d(17),nn.ReLU(inplace=True),nn.Linear(17,10))
layers = [learn.enc,learn.bn,lin]
clf_model = nn.Sequential(*layers)

clf = Learner(learn.data,clf_model,metrics=accuracy,layer_groups=layers)

# %%
def freeze_model(model):
    model.eval()
    for params in model.parameters():
        params.requires_grad = False
        
freeze_model(learn.encode)

lin = nn.Sequential(nn.Linear(24,18),nn.BatchNorm1d(18),nn.ReLU(inplace=True),nn.Linear(18,10))
layers = [learn.encode,lin]
clf_model = nn.Sequential(*layers)

clf = Learner(learn.data,clf_model,metrics=accuracy)

# %%
clf.path = Path()
clf.lr_find()
clf.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-2
clf.fit_one_cycle(100,lr)

clf.data = valid_data
clf.data.batch_size = 4096

pred,y = clf.get_preds(DatasetType.Train)
score = (pred.argmax(dim=1) == y).float().mean().item()

# %%
score
# Out:
# 0.8479701280593872

# %%
data, valid_data = get_data(160, gray=False)

# %%
clf = cnn_learner(data,models.resnet18,metrics = accuracy)
clf.path = Path()
clf.lr_find()
clf.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.plot_2d_latents(DatasetType.Train)
# Out:
# Computing the TSNE projection

# %%
score
# Out:
# 0.9129464030265808

# %%
data, valid_data = get_data(640)

# %%
clf = cnn_learner(data,models.resnet18,metrics = accuracy)

# %%
learn.plot_rec_steps()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
learn.plot_2d_latents(DatasetType.Train)
# Out:
# Computing the TSNE projection

# %%
learn.plot_rec()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
ds_size = int(128 * 1.25)
data,valid_data = get_data(ds_size,bs=64)

# %%
results = []
n = 10
pretrained = "no"
learn.path = Path()
learn.data = data

for i in range(n):
    size = PARAMS["size"]
    conv = PARAMS["conv"]
    act_fn = PARAMS["act_fn"]
    bn = PARAMS["bn"]
    rec_loss = PARAMS["rec_loss"]

    nfs = PARAMS["nfs_enc"]
    ks = PARAMS["ks_enc"]
    # enc = create_encoder(nfs,ks,conv=conv,bn=bn,act_fn=act_fn)
    enc = create_encoder_denseblock(3,4)

    nfs = PARAMS["nfs_bn"]
    vae_bn = VAEBottleneck(nfs,act_fn)

    nfs = PARAMS["nfs_dec"]
    ks = PARAMS["ks_dec"]
    dec_conv = create_decoder(nfs,ks,conv=conv,bn=bn,act_fn=act_fn)
    dec = SpatialDecoder2D(dec_conv,size)

    learn = AutoEncoderLearner(data,rec_loss,enc,vae_bn,dec)
    kl_hook = VAEHook(learn,beta=PARAMS["beta_kl"])

    n_z = PARAMS["nfs_bn"][-1]
    lin = nn.Sequential(nn.Linear(32,n_z),nn.BatchNorm1d(n_z),nn.ReLU(inplace=True),nn.Linear(n_z,10))
    layers = [learn.enc,learn.bn,lin]
    clf_model = nn.Sequential(*layers)
    
    clf = Learner(learn.data,clf_model,metrics=accuracy)
    lr = 1e-1 / 2
    clf.fit_one_cycle(125,lr)

    clf.data = valid_data
    clf.data.batch_size = 4096

    pred,y = clf.get_preds(DatasetType.Train)
    score = (pred.argmax(dim=1) == y).float().mean().item()
    result = {"data_size":ds_size,"pretrained":pretrained,"score":score}
    results.append(result)

pd.DataFrame(results).to_csv(f"{str(ds_size)}_{pretrained}.csv",index=None)

# %%
size = PARAMS["size"]
conv = PARAMS["conv"]
act_fn = PARAMS["act_fn"]
bn = PARAMS["bn"]
rec_loss = PARAMS["rec_loss"]

nfs = PARAMS["nfs_enc"]
ks = PARAMS["ks_enc"]
# enc = create_encoder(nfs,ks,conv=conv,bn=bn,act_fn=act_fn)
enc = create_encoder_denseblock(3,4)

nfs = PARAMS["nfs_bn"]
vae_bn = VAEBottleneck(nfs,act_fn)

nfs = PARAMS["nfs_dec"]
ks = PARAMS["ks_dec"]
dec_conv = create_decoder(nfs,ks,conv=conv,bn=bn,act_fn=act_fn)
dec = SpatialDecoder2D(dec_conv,size)

learn = AutoEncoderLearner(data,rec_loss,enc,vae_bn,dec)
kl_hook = VAEHook(learn,beta=PARAMS["beta_kl"])

n_z = PARAMS["nfs_bn"][-1]
lin = nn.Sequential(nn.Linear(32,n_z),nn.BatchNorm1d(n_z),nn.ReLU(inplace=True),nn.Linear(n_z,10))
layers = [learn.enc,learn.bn,lin]
clf_model = nn.Sequential(*layers)

clf = Learner(learn.data,clf_model,metrics=accuracy)
lr = 1e-2
clf.fit_one_cycle(125,lr)

clf.data = valid_data
clf.data.batch_size = 4096

pred,y = clf.get_preds(DatasetType.Train)
score = (pred.argmax(dim=1) == y).float().mean().item()
result = {"data_size":ds_size,"pretrained":pretrained,"score":score}
result
# Out:
# {'data_size': 640, 'pretrained': 'MNIST_TINY', 'score': 0.9639369249343872}

# %%
# !ls models
# Out:
# model_mnist_tiny.pth  model_nz_20.pth  model.pth  tmp.pth  vae_experiment.pth

# %%
learn.path = Path()
learn.load("model")
# Out:
# VisionAELearner(data=ImageDataBunch;
#
# Train: LabelList (512 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 6,4,2,6,7
# Path: /;
#
# Valid: LabelList (128 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 7,0,3,4,1
# Path: /;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (0): ConvBnRelu(
#         (conv): Conv2d(1, 4, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#         (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#     (1): Sequential(
#       (0): DenseBlock(
#         (conv): ConvBnRelu(
#           (conv): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#     (2): Sequential(
#       (0): DenseBlock(
#         (conv): ConvBnRelu(
#           (conv): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#     (3): Sequential(
#       (0): DenseBlock(
#         (conv): ConvBnRelu(
#           (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#   )
#   (1): VAEBottleneck(
#     (fc): Sequential(
#       (0): VAELayer(
#         (blinear): VAELinear(
#           (linear): Linear(in_features=512, out_features=32, bias=True)
#           (mu_linear): Linear(in_features=32, out_features=32, bias=True)
#           (logvar_linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (sampler): NormalSampler()
#       )
#     )
#   )
#   (2): SpatialDecoder2D(
#     (dec): Sequential(
#       (0): ConvBnRelu(
#         (conv): PointwiseConv(
#           (conv): Conv2d(34, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (1): ConvBnRelu(
#         (conv): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (2): ConvBnRelu(
#         (conv): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (3): ConvBnRelu(
#         (conv): Conv2d(4, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=<bound method AutoEncoderLearner.loss_func of ...>, metrics=[], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[ReplaceTargetCallback
# learn: ...], layer_groups=[Sequential(
#   (0): Conv2d(1, 4, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace)
#   (3): ReflectionPad2d([1, 1, 1, 1])
#   (4): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (5): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU(inplace)
#   (7): ReflectionPad2d([1, 1, 1, 1])
#   (8): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (9): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU(inplace)
#   (11): ReflectionPad2d([1, 1, 1, 1])
#   (12): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (13): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU(inplace)
#   (15): ReflectionPad2d([1, 1, 1, 1])
#   (16): Linear(in_features=512, out_features=32, bias=True)
#   (17): Linear(in_features=32, out_features=32, bias=True)
#   (18): Linear(in_features=32, out_features=32, bias=True)
#   (19): NormalSampler()
#   (20): Conv2d(34, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (21): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): ReLU(inplace)
#   (23): Conv2d(64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (24): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (25): ReLU(inplace)
#   (26): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (27): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (28): ReLU(inplace)
#   (29): Conv2d(4, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (30): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (31): ReLU(inplace)
# )], add_time=True, silent=False)

# %%
pretrained = "MNIST_512"

n_z = PARAMS["nfs_bn"][-1]
lin = nn.Sequential(nn.Linear(32,20),nn.BatchNorm1d(20),nn.ReLU(inplace=True),nn.Linear(20,10))
layers = [learn.enc,learn.bn,lin]
clf_model = nn.Sequential(*layers)

clf = Learner(learn.data,clf_model,metrics=accuracy,layer_groups = layers)
lr = 1e-2
clf.fit_one_cycle(110,(lr/100,lr/10,lr))

clf.data = valid_data
clf.data.batch_size = 4096

pred,y = clf.get_preds(DatasetType.Train)
score = (pred.argmax(dim=1) == y).float().mean().item()
result = {"data_size":ds_size,"pretrained":pretrained,"score":score}
result
# Out:
# {'data_size': 640, 'pretrained': 'MNIST_512', 'score': 0.9509800672531128}

# %%
learn.plot_rec()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
learn.plot_2d_latents(DatasetType.Train)
# Out:
# Computing the TSNE projection

# %%
results = []
n = 10
pretrained = "MNIST_512"
learn.path = Path()
learn.data = data

for i in range(n):
    learn.load("model")

    n_z = PARAMS["nfs_bn"][-1]
    lin = nn.Sequential(nn.Linear(32,n_z),nn.BatchNorm1d(n_z),nn.ReLU(inplace=True),nn.Linear(n_z,10))
    layers = [learn.enc,learn.bn,lin]
    clf_model = nn.Sequential(*layers)
    
    clf = Learner(learn.data,clf_model,metrics=accuracy,layer_groups = layers)
    lr = 1e-2
    clf.fit_one_cycle(125,max_lr=(lr / 100,lr / 10,lr))

    clf.data = valid_data
    clf.data.batch_size = 4096

    pred,y = clf.get_preds(DatasetType.Train)
    score = (pred.argmax(dim=1) == y).float().mean().item()
    result = {"data_size":ds_size,"pretrained":pretrained,"score":score}
    results.append(result)

pd.DataFrame(results).to_csv(f"{str(ds_size)}_{pretrained}.csv",index=None)

# %%
results = []
n = 10
pretrained = "MNIST_TINY"
learn.path = Path()
learn.data = data

for i in range(n):
    learn.load("model_mnist_tiny")

    n_z = PARAMS["nfs_bn"][-1]
    lin = nn.Sequential(nn.Linear(32,n_z),nn.BatchNorm1d(n_z),nn.ReLU(inplace=True),nn.Linear(n_z,10))
    layers = [learn.enc,learn.bn,lin]
    clf_model = nn.Sequential(*layers)
    
    clf = Learner(learn.data,clf_model,metrics=accuracy,layer_groups = layers)
    lr = 1e-1 / 2
    clf.fit_one_cycle(125,max_lr=(lr / 100,lr / 10,lr))

    clf.data = valid_data
    clf.data.batch_size = 4096

    pred,y = clf.get_preds(DatasetType.Train)
    score = (pred.argmax(dim=1) == y).float().mean().item()
    result = {"data_size":ds_size,"pretrained":pretrained,"score":score}
    results.append(result)

pd.DataFrame(results).to_csv(f"{str(ds_size)}_{pretrained}.csv",index=None)

# %%
learn.path = Path()
learn.load("model")
learn.data = data

n_z = PARAMS["nfs_bn"][-1]
lin = nn.Sequential(nn.Linear(32,n_z),nn.BatchNorm1d(n_z),nn.ReLU(inplace=True),nn.Linear(n_z,10))
layers = [learn.enc,learn.bn,lin]
clf_model = nn.Sequential(*layers)

clf = Learner(learn.data,clf_model,metrics=accuracy,layer_groups=layers)
lr = 1e-1 / 2

# %%
clf.fit_one_cycle(125,max_lr = (lr /100,lr/10,lr))

clf.data = valid_data
clf.data.batch_size = 2048

pred,y = clf.get_preds(DatasetType.Train)
score = (pred.argmax(dim=1) == y).float().mean().item()
result = {"data_size":ds_size,"pretrained":"MNIST_512","score":score}
results.append(result)
# Out:
# ImageDataBunch;
#
# Train: LabelList (59872 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 5,5,5,5,5
# Path: /;
#
# Valid: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: /;
#
# Test: None

# %%
def plot_shades(learn,x=None,i=0,n_perturb = 13, mag_perturb = 3, ax = None,gray = True):
    """Plot the reconstruction of the """
    learn.model.cpu()
    if not isinstance(x,torch.Tensor):
        x,y = learn.data.one_batch()

    x = x[i].unsqueeze(0)

    # We get the latent code
    z = learn.encode(x)
    n_z = z.shape[1]

    # We create a scale of perturbations
    mag_perturb = np.abs(mag_perturb)
    scale_perturb = np.linspace(-mag_perturb,mag_perturb,n_perturb)

    if not ax:
        fig, ax = plt.subplots(n_z,n_perturb, figsize=(20,20))
        fig.tight_layout()

    for i in range(n_z):
        for (j,perturb) in enumerate(scale_perturb):
            # For each z_i we add a minor perturbation
            z_perturb = z.clone()
            z_perturb[0,i] += perturb

            # We reconstruct our image
            x_rec = learn.decode(z_perturb)
            
            # We plot it in the grid
            img = x_rec.squeeze(0).permute(1,2,0).detach().numpy()
            if gray:
                img = np.concatenate([img,img,img],axis = -1)
            ax[i][j].set_axis_off()
            ax[i][j].imshow(img)
            ax[i][j].set_title(f"z_{i} with {round(perturb * 1e2) / 1e2}")

# %%
from sklearn.ensemble import RandomForestClassifier
from functools import partial
from fastai.core import parallel

params = {"criterion" : "entropy",
     "max_depth" : 5,
     "max_features" : 0.8,
     "n_jobs" : -1}

def create_random_forest(learn,n_rf,bs = 512,n_batch = 1,**kwargs):
    rfs = []
    learn.data.batch_size = bs
    for i in range(n_rf):
        z,y = learn.get_latents(DatasetType.Train,n_batch=n_batch)
        z,y = z.numpy(),y.numpy()
        
        rf = RandomForestClassifier(**kwargs)
        rf.fit(z,y)
        rfs.append(rf)
        
    return rfs

def vote(a,threshold = 0.5,keep_vote=False):
    values,count = np.unique(a,return_counts=True)
    total = np.sum(count)
    max_count = np.argmax(count)
    score = count[max_count] / total
    
    if score < threshold:
        output = -1
    else:
        output = values[max_count]
    
    if keep_vote:
        return output,score
    else:
        return output
    
        
def compute_score(y_pred,y_valid):
    """Compute the number of times the trees agree and what is their accuracy on the agreed votes"""
    idx = (y_pred != -1)
    vote_pct = np.sum(idx) / len(idx)
    score = (y_pred[idx] == y_valid[idx]).mean()
    return vote_pct,score

# %%
def rf_predict(rfs:list,z_valid,threshold=0.5,keep_vote=False):

    rfs = listify(rfs)
    
    y = []
    for rf in rfs:    
        for tree in rf.estimators_:
            y.append(tree.predict(z_valid).reshape(-1,1))
    # We compute the prediction of each tree of each forest
    y = np.concatenate(y,axis = -1).astype(int)
    
    # We make them vote
    vote_fct = partial(vote,threshold=threshold,keep_vote=keep_vote)
    y_pred = np.apply_along_axis(vote_fct,1,y)
    
    return y_pred

def compute_metrics(learn,z_valid,y_valid,n_batch,n_estimators,n_rf,bs = 512,threshold=0.5,keep_vote=False):
    # First we add the data set with the right size to our learner
    params["n_estimators"] = n_estimators
    
    rfs = create_random_forest(learn,n_rf,n_batch=n_batch,bs=bs,**params)
    
    y_pred = rf_predict(rfs,z_valid,threshold,keep_vote)
    
    output = {"train_size":n_batch*bs,"n_estimators":n_estimators,"n_rf":n_rf}
    output["vote_pct"], output["score"] = compute_score(y_pred,y_valid)
    
    return output

# %%
learn.path = Path()
learn.load("model_mnist_tiny")
# Out:
# VisionAELearner(data=ImageDataBunch;
#
# Train: LabelList (512 items)
# x: ImageList
# Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28)
# y: CategoryList
# 4,8,0,3,3
# Path: /;
#
# Valid: LabelList (128 items)
# x: ImageList
# Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28),Image (3, 28, 28)
# y: CategoryList
# 9,9,4,0,5
# Path: /;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (0): ConvBnRelu(
#         (conv): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (1): ResBlock(
#         (conv1): ConvBnRelu(
#           (conv): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (conv2): ConvBnRelu(
#           (conv): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (2): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#     (1): Sequential(
#       (0): DenseBlock(
#         (conv): ResBlock(
#           (conv1): ConvBnRelu(
#             (conv): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#           (conv2): ConvBnRelu(
#             (conv): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#         )
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#     (2): Sequential(
#       (0): DenseBlock(
#         (conv): ResBlock(
#           (conv1): ConvBnRelu(
#             (conv): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#           (conv2): ConvBnRelu(
#             (conv): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#         )
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#     (3): Sequential(
#       (0): DenseBlock(
#         (conv): ResBlock(
#           (conv1): ConvBnRelu(
#             (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#           (conv2): ConvBnRelu(
#             (conv): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_fn): ReLU(inplace)
#           )
#         )
#       )
#       (1): Downsample(
#         (pad): ReflectionPad2d([1, 1, 1, 1])
#       )
#     )
#   )
#   (1): VAEBottleneck(
#     (fc): Sequential(
#       (0): VAELayer(
#         (blinear): VAELinear(
#           (linear): Linear(in_features=128, out_features=24, bias=True)
#           (mu_linear): Linear(in_features=24, out_features=24, bias=True)
#           (logvar_linear): Linear(in_features=24, out_features=24, bias=True)
#         )
#         (sampler): NormalSampler()
#       )
#     )
#   )
#   (2): Sequential(
#     (0): SpatialDecoder2D()
#     (1): Sequential(
#       (0): ConvBnRelu(
#         (conv): PointwiseConv(
#           (conv): Conv2d(26, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (1): ConvBnRelu(
#         (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (2): ConvBnRelu(
#         (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (3): ConvBnRelu(
#         (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (4): ConvBnRelu(
#         (conv): Conv2d(8, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (5): ConvBnRelu(
#         (conv): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (6): ConvBnRelu(
#         (conv): Conv2d(2, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=<bound method AutoEncoderLearner.loss_func of ...>, metrics=[], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[ReplaceTargetCallback
# learn: ...], layer_groups=[Sequential(
#   (0): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace)
#   (3): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU(inplace)
#   (6): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (7): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU(inplace)
#   (9): ReflectionPad2d([1, 1, 1, 1])
#   (10): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (11): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU(inplace)
#   (13): Conv2d(2, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (14): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (15): ReLU(inplace)
#   (16): ReflectionPad2d([1, 1, 1, 1])
#   (17): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (18): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): ReLU(inplace)
#   (20): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (21): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): ReLU(inplace)
#   (23): ReflectionPad2d([1, 1, 1, 1])
#   (24): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (25): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): ReLU(inplace)
#   (27): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (28): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (29): ReLU(inplace)
#   (30): ReflectionPad2d([1, 1, 1, 1])
#   (31): Linear(in_features=128, out_features=24, bias=True)
#   (32): Linear(in_features=24, out_features=24, bias=True)
#   (33): Linear(in_features=24, out_features=24, bias=True)
#   (34): NormalSampler()
#   (35): SpatialDecoder2D()
#   (36): Conv2d(26, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (37): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (38): ReLU(inplace)
#   (39): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (40): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (41): ReLU(inplace)
#   (42): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (43): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (44): ReLU(inplace)
#   (45): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (46): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (47): ReLU(inplace)
#   (48): Conv2d(8, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (49): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (50): ReLU(inplace)
#   (51): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (52): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (53): ReLU(inplace)
#   (54): Conv2d(2, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (55): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (56): ReLU(inplace)
# )], add_time=True, silent=False)

# %%
data,valid_data = get_data(512,bs = 128,size=28)
learn.data= valid_data
valid_data.batch_size = 2048
z_valid,y_valid = learn.get_latents(DatasetType.Train)
z_valid,y_valid = z_valid.numpy(),y_valid.numpy()
learn.data = data

# %%
rfs = create_random_forest(learn,n_rf=1,n_batch=4,bs=128,n_estimators=100)

# %%
rf = rfs[0]

# %%
rf.feature_importances_
# Out:
# array([0.029542, 0.029077, 0.032541, 0.02915 , 0.037793, 0.023994, 0.016823, 0.061807, 0.018782, 0.033741, 0.036322,
#        0.05187 , 0.019597, 0.049725, 0.033302, 0.019435, 0.02733 , 0.016185, 0.021424, 0.061177, 0.020464, 0.043806,
#        0.024109, 0.02708 , 0.029615, 0.013438, 0.030335, 0.03441 , 0.035065, 0.017817, 0.038549, 0.035693])

# %%
y_pred = rf_predict(rfs,z_valid,threshold=0.0)
compute_score(y_pred,y_valid)

# %%
n_batchs = [1,2,4]
n_rf = 10
n_estimators = 10

output = []
for n_batch in n_batchs:
    rfs = create_random_forest(learn,n_rf=10,n_batch=n_batch,bs=128,n_estimators=20)
    for threshold in np.arange(0,1,0.1):
        y_pred = rf_predict(rfs,z_valid,threshold=threshold,keep_vote=False)
        vote_pct,score = compute_score(y_pred,y_valid)

        output.append({"n_batch":n_batch,"threshold":threshold,"vote_pct":vote_pct,"score":score})

# %%
rf = rfs[0]

# %%
names = [f"z_{i}" for i in range(len(rf.feature_importances_))]
feats = dict(zip(names,rf.feature_importances_))

# %%
sorted(feats.items(),key = lambda x:x[1],reverse=True)
# Out:
# [('z_7', 0.06180651787858639),
#  ('z_19', 0.06117720095608158),
#  ('z_11', 0.05187019665598493),
#  ('z_13', 0.04972511789797899),
#  ('z_21', 0.043805992047271126),
#  ('z_30', 0.038549163949958894),
#  ('z_4', 0.03779332610113403),
#  ('z_10', 0.036321968380876465),
#  ('z_31', 0.03569287637601409),
#  ('z_28', 0.03506541292529257),
#  ('z_27', 0.034409699893377874),
#  ('z_9', 0.033741154665328746),
#  ('z_14', 0.0333021198276269),
#  ('z_2', 0.03254050987443108),
#  ('z_26', 0.030335032674192394),
#  ('z_24', 0.029615283936970088),
#  ('z_0', 0.029542371911704092),
#  ('z_3', 0.029149805679901865),
#  ('z_1', 0.029076680906856098),
#  ('z_16', 0.027330429952939307),
#  ('z_23', 0.027080420173109507),
#  ('z_22', 0.024108929067640377),
#  ('z_5', 0.02399449647724164),
#  ('z_18', 0.021423581689919344),
#  ('z_20', 0.020463831404679847),
#  ('z_12', 0.019597358163759807),
#  ('z_15', 0.019435226294155707),
#  ('z_8', 0.01878180005119742),
#  ('z_29', 0.017817317840739613),
#  ('z_6', 0.016823016180356407),
#  ('z_17', 0.016185491902428784),
#  ('z_25', 0.013437668262264092)]

# %%
x_valid = np.concatenate([z_valid,y_valid.reshape(-1,1)],axis=1)

# %%
idx = x_valid[:,17].argsort()

# %%
df = pd.DataFrame(x_valid)

# %%
df.columns = [f"z_{i}" for i in range(len(rf.feature_importances_))] + ["target"]

# %%
df[["z_0","target"]].groupby("target").mean()
# Out:
#              z_0
# target
# 0.0     1.734377
# 1.0     1.720294
# 2.0     1.552565
# 3.0     1.746271
# 4.0     1.670507
# 5.0     1.680219
# 6.0     1.610682
# 7.0     1.694823
# 8.0     1.594755
# 9.0     1.701031

# %%
pd.DataFrame(output)
# Out:
#     n_batch     score  threshold  vote_pct
# 0         1  0.815497        0.0  1.000000
# 1         1  0.815497        0.1  1.000000
# 2         1  0.829619        0.2  0.973094
# 3         1  0.927166        0.3  0.715484
# 4         1  0.980141        0.4  0.462066
# 5         1  0.994024        0.5  0.262022
# 6         1  0.997864        0.6  0.126111
# 7         1  0.999622        0.7  0.044602
# 8         1  1.000000        0.8  0.007392
# 9         1       NaN        0.9  0.000000
# 10        2  0.832099        0.0  1.000000
# 11        2  0.832099        0.1  1.000000
# 12        2  0.839333        0.2  0.986968
# 13        2  0.908167        0.3  0.816810
# 14        2  0.964309        0.4  0.608095
# 15        2  0.988487        0.5  0.422666
# 16        2  0.996061        0.6  0.256499
# 17        2  0.998160        0.7  0.137274
# 18        2  0.999136        0.8  0.058476
# 19        2  1.000000        0.9  0.011668
# 20        4  0.848094        0.0  1.000000
# 21        4  0.848094        0.1  1.000000
# 22        4  0.853297        0.2  0.990706
# 23        4  0.912800        0.3  0.849205
# 24        4  0.963079        0.4  0.668996
# 25        4  0.986222        0.5  0.496144
# 26        4  0.994937        0.6  0.332587
# 27        4  0.998135        0.7  0.198646
# 28        4  0.998994        0.8  0.100451
# 29        4  0.999429        0.9  0.029482

# %%
# 10 rf 20 est
df = pd.DataFrame(output)
df
# Out:
#     n_batch     score  threshold  vote_pct
# 0         1  0.828900        0.0  1.000000
# 1         1  0.828900        0.1  1.000000
# 2         1  0.849885        0.2  0.958765
# 3         1  0.938130        0.3  0.689874
# 4         1  0.981417        0.4  0.437618
# 5         1  0.994973        0.5  0.237793
# 6         1  0.998282        0.6  0.107809
# 7         1  0.998667        0.7  0.037901
# 8         1  1.000000        0.8  0.007425
# 9         1  1.000000        0.9  0.000034
# 10        2  0.854004        0.0  1.000000
# 11        2  0.854004        0.1  1.000000
# 12        2  0.863713        0.2  0.981176
# 13        2  0.931050        0.3  0.790460
# 14        2  0.976801        0.4  0.581358
# 15        2  0.993946        0.5  0.383823
# 16        2  0.997780        0.6  0.212352
# 17        2  0.999829        0.7  0.098700
# 18        2  0.999550        0.8  0.037396
# 19        2  1.000000        0.9  0.006819
# 20        4  0.863062        0.0  1.000000
# 21        4  0.863062        0.1  1.000000
# 22        4  0.870031        0.2  0.987288
# 23        4  0.927713        0.3  0.840618
# 24        4  0.969934        0.4  0.658574
# 25        4  0.990639        0.5  0.473027
# 26        4  0.996932        0.6  0.296387
# 27        4  0.999170        0.7  0.162194
# 28        4  0.999763        0.8  0.070986
# 29        4  1.000000        0.9  0.018992

# %%
# 10 rf 10 est
df = pd.DataFrame(output)
df
# Out:
#     n_batch     score  threshold  vote_pct
# 0         1  0.811406        0.0  1.000000
# 1         1  0.811406        0.1  1.000000
# 2         1  0.830061        0.2  0.963042
# 3         1  0.927842        0.3  0.686254
# 4         1  0.974765        0.4  0.463059
# 5         1  0.993222        0.5  0.260826
# 6         1  0.998884        0.6  0.105570
# 7         1  1.000000        0.7  0.036268
# 8         1  1.000000        0.8  0.011146
# 9         1  1.000000        0.9  0.000673
# 10        2  0.847387        0.0  1.000000
# 11        2  0.847387        0.1  1.000000
# 12        2  0.856161        0.2  0.984442
# 13        2  0.929339        0.3  0.791571
# 14        2  0.972512        0.4  0.592319
# 15        2  0.991351        0.5  0.387392
# 16        2  0.997057        0.6  0.205954
# 17        2  0.998777        0.7  0.096393
# 18        2  0.999612        0.8  0.043423
# 19        2  1.000000        0.9  0.014009
# 20        4  0.858483        0.0  1.000000
# 21        4  0.858483        0.1  1.000000
# 22        4  0.864045        0.2  0.990015
# 23        4  0.920002        0.3  0.845888
# 24        4  0.963106        0.4  0.674518
# 25        4  0.987749        0.5  0.489275
# 26        4  0.995955        0.6  0.303879
# 27        4  0.998771        0.7  0.164399
# 28        4  0.999777        0.8  0.075599
# 29        4  1.000000        0.9  0.019043

# %%
# 1 rf 100 estimators
df = pd.DataFrame(output)
df
# Out:
#       score  threshold  vote_pct
# 0  0.880790        0.0  1.000000
# 1  0.880790        0.1  1.000000
# 2  0.886127        0.2  0.990670
# 3  0.936742        0.3  0.863142
# 4  0.973407        0.4  0.708880
# 5  0.989955        0.5  0.539934
# 6  0.996873        0.6  0.351371
# 7  0.999206        0.7  0.197754
# 8  0.999613        0.8  0.090053
# 9  1.000000        0.9  0.021031

# %%
df = pd.DataFrame(output)
df
# Out:
#       score  threshold  vote_pct
# 0  0.903774        0.0  1.000000
# 1  0.903774        0.1  1.000000
# 2  0.911677        0.2  0.985822
# 3  0.960666        0.3  0.828177
# 4  0.984690        0.4  0.643555
# 5  0.995377        0.5  0.433838
# 6  0.999335        0.6  0.235997
# 7  0.999829        0.7  0.102138
# 8  1.000000        0.8  0.034040
# 9  1.000000        0.9  0.003418

# %%
df = pd.DataFrame(output)
df
# Out:
#       score  threshold  vote_pct
# 0  0.903878        0.0  1.000000
# 1  0.903878        0.1  1.000000
# 2  0.910049        0.2  0.989118
# 3  0.956966        0.3  0.855033
# 4  0.983141        0.4  0.696150
# 5  0.995288        0.5  0.503331
# 6  0.998818        0.6  0.295183
# 7  0.999870        0.7  0.134051
# 8  1.000000        0.8  0.041277
# 9  1.000000        0.9  0.002546

# %%
df = pd.DataFrame(output)
df.plot
# Out:
#       score  threshold  vote_pct
# 0  0.924003        0.0  1.000000
# 1  0.924003        0.1  1.000000
# 2  0.930633        0.2  0.989240
# 3  0.971681        0.3  0.875645
# 4  0.991493        0.4  0.731794
# 5  0.997519        0.5  0.541207
# 6  0.998880        0.6  0.311349
# 7  0.999731        0.7  0.129656
# 8  1.000000        0.8  0.030744
# 9  1.000000        0.9  0.000575

# %%
pred = rf_predict(rfs,z_valid,threshold=0.5,keep_vote=True)

# %%
pred.shape
# Out:
# (57344, 2)

# %%
plt.plot(df.vote_pct,df.score)

# %%
correct = (pred[:,0] == y_valid).reshape(-1,1)

# %%
pred = np.concatenate((pred,correct),axis=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
clf = LogisticRegression()
clf.fit(pred[:,1].reshape(-1,1),pred[:,2].reshape(-1,1))
# Out:
# /data/anaconda/envs/naox3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /data/anaconda/envs/naox3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /data/anaconda/envs/naox3/lib/python3.7/site-packages (0.9.0)

# %%
import statsmodels.api as sm

X = pred[:,1]
X = sm.add_constant(X)
y = pred[:,2]

model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
print("p-value of Fischer test for salaire against cheveux %f4" % model.f_pvalue)
# Out:
# p-value of Fischer test for salaire against cheveux 0.0000004

# %%
model.params
# Out:
# array([-0.776689,  2.576741])

# %%
output = compute_metrics(learn,z_valid,y_valid,n_batch=1,bs=128,n_estimators=10,n_rf=1,threshold=0.5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-bddd9e9652aa> in <module>
# ----> 1 output = compute_metrics(learn,z_valid,y_valid,n_batch=1,bs=128,n_estimators=10,n_rf=1,threshold=0.5)
#
# <ipython-input-16-e2fc0b0586f5> in compute_metrics(learn, z_valid, y_valid, n_batch, n_estimators, n_rf, bs, threshold, keep_vote)
#      25
#      26     output = {"train_size":n_batch*bs,"n_estimators":n_estimators,"n_rf":n_rf}
# ---> 27     output["vote_pct"], output["score"] = compute_score(y_pred,y_valid)
#      28
#      29     return output
#
# <ipython-input-9-508c2208b0bf> in compute_score(y_pred, y_valid)
#      38     idx = (y_pred != -1)
#      39     vote_pct = np.sum(idx) / len(idx)
# ---> 40     score = (y_pred[idx] == y_valid[idx]).mean()
#      41     return vote_pct,score
#
# IndexError: too many indices for array

# %%
rfs = create_random_forest(learn,n_rf=10,n_estimators = 10,bs = 128,n_batch = 1,**params)

# %%
rf = rfs[0]

# %%
x,y = learn.data.one_batch(DatasetType.Valid)
learn.model.cpu()
with torch.no_grad():
    z = learn.encode(x)

# %%
df = dict(zip( np.arange(len(rf.feature_importances_)),rf.feature_importances_))

# %%
z.cl

# %%
z[0].shape
# Out:
# torch.Size([24])

# %%
import warnings
warnings.filterwarnings("ignore")

j = 12
bs = 10
z = z[:bs]

mag_perturb = 1
n_perturb = 20

mag_perturb = np.abs(mag_perturb)
scale_perturb = np.linspace(-mag_perturb,mag_perturb,n_perturb)
ax = None
if not ax:
    fig, ax = plt.subplots(bs,n_perturb, figsize=(30,30))
    fig.tight_layout()
for row in range(bs):
    for (col,eps) in enumerate(scale_perturb):
        z_perturb = z.clone()
        z_perturb = z_perturb[row]
        z_perturb[col] += eps
        x_rec = learn.decode(z_perturb.unsqueeze(0))
        
        x_rec = x_rec.detach()[0].permute(1,2,0).numpy()
        img = np.concatenate([x_rec,x_rec,x_rec],axis = -1)
        ax[row][col].imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
sorted(df.items(),key = lambda x : x[1],reverse = True)
# Out:
# [(12, 0.15131273714585355),
#  (11, 0.09151100660864651),
#  (10, 0.08931936001213468),
#  (14, 0.0644866349863583),
#  (2, 0.05973366867132986),
#  (3, 0.051156075291391566),
#  (0, 0.0486653631437793),
#  (21, 0.04788081256871918),
#  (20, 0.04497470289771256),
#  (18, 0.04239235347757288),
#  (13, 0.04235528160979805),
#  (6, 0.041999027578566626),
#  (4, 0.04018967725491911),
#  (9, 0.028892950798016726),
#  (19, 0.023005326461794526),
#  (23, 0.019437998351800795),
#  (15, 0.01925211437554033),
#  (1, 0.016776599790886186),
#  (17, 0.015940078351748092),
#  (7, 0.01362969626916929),
#  (5, 0.013451485369654717),
#  (16, 0.01342869080522895),
#  (22, 0.01033910414382436),
#  (8, 0.009869254035553868)]

# %%
rf.decision_path(z)
# Out:
# (<512x2700 sparse matrix of type '<class 'numpy.int64'>'
#  	with 42448 stored elements in Compressed Sparse Row format>,
#  array([   0,  257,  510,  791, 1058, 1327, 1602, 1875, 2156, 2427, 2700]))

# %%
output
# Out:
# {'train_size': 128,
#  'n_estimators': 10,
#  'n_rf': 10,
#  'vote_pct': 0.3154296875,
#  'score': 0.998562582927908}

# %%
# train_size = [1024,2048,4096]
n_batch = [1]
# n_rf = [1,1,10,20,1]
n_rf = [1,10,20,10,50,10]
# n_estimators = [10,100,10,10,200]
n_estimators = [10,10,10,20,10,50]

outputs = []

for n in n_batch:
    for n_r,n_e in zip(n_rf,n_estimators):
        print(f"Computing with {n_r} forests and {n_e} trees")
        output = compute_metrics(learn,z_valid,y_valid,n_batch=n,n_estimators=n_e,n_rf=n_r,bs=128)
        outputs.append(output)

# %%
results = pd.DataFrame(outputs)
results.to_csv("results_tiny.csv",index = None)

# %%
results["mean"] = (results["vote_pct"] + results["score"]) * 0.5

# %%
results
# Out:
#    n_estimators  n_rf     score  train_size  vote_pct
# 0            10     1  0.802736         128  0.500943
# 1            10    10  0.953005         128  0.345383
# 2            10    20  0.963487         128  0.336628
# 3            20    10  0.961274         128  0.335213
# 4            10    50  0.958837         128  0.344003
# 5            50    10  0.957781         128  0.333008

# %%
params = {"n_estimators":200,
         "criterion" : "entropy",
         "max_depth" : 10,
         "max_features" : 0.8,
         "n_jobs" : -1}

n_rf = 1

rfs = create_random_forest(learn,n_rf,**params)




    
y_pred = np.apply_along_axis(vote,1,y)

# %%
# Single rf : 3000 samples
idx = (y_pred != -1)
print(np.sum(idx) / len(idx))
(y_pred[idx] == y_valid[idx]).mean()
# Out:
# 0.8170460668103449
# 0.8694926431191526

# %%
# Multiple rf : 3000 samples
idx = (y_pred != -1)
print(np.sum(idx) / len(idx))
(y_pred[idx] == y_valid[idx]).mean()
# Out:
# 0.7785391971982759
# 0.931832435822574

# %%
uncert = (y_pred == -1 )

# %%
v,c = np.unique(learn.data.valid_ds.y[uncert].items,return_counts=True)

# %%
df = pd.DataFrame({"index" : v,"count" : c})
# Out:
#    index  count
# 0      0    423
# 1      1    138
# 2      2    790
# 3      3    768
# 4      4    586
# 5      5    685
# 6      6    362
# 7      7    701
# 8      8   1513
# 9      9    595

# %%
df.sort_values("count")
# Out:
#    index  count
# 1      1    138
# 6      6    362
# 0      0    423
# 4      4    586
# 9      9    595
# 5      5    685
# 7      7    701
# 3      3    768
# 2      2    790
# 8      8   1513

# %%
# Multiple rf
idx = (y_pred != -1)
print(np.sum(idx) / len(idx))
(y_pred[idx] == y_valid[idx]).mean()
# Out:
# 0.8633125
# 0.9392118535678949

# %%
rf = rfs[0]

# %%
labels = [f"z_{i}" for i in range(len(rf.feature_importances_))]
feats = rf.feature_importances_
df = pd.DataFrame(labels,feats)

# %%
df.sort_index()
# Out:
#              0
# 0.006576  z_12
# 0.006695   z_7
# 0.008128  z_24
# 0.008643  z_29
# 0.010957  z_17
# 0.011098  z_16
# 0.011183  z_28
# 0.013577  z_14
# 0.014662  z_18
# 0.016579  z_10
# 0.019140  z_30
# 0.020081  z_26
# 0.020296  z_22
# 0.023688   z_8
# 0.024015   z_1
# 0.025066  z_27
# 0.025772   z_0
# 0.027200   z_2
# 0.027318  z_23
# 0.030210   z_6
# 0.031544  z_20
# 0.035423   z_9
# 0.038668  z_31
# 0.038934   z_4
# 0.045502   z_3
# 0.045804  z_11
# 0.046794  z_15
# 0.049603  z_19
# 0.055590  z_13
# 0.068220  z_21
# 0.075567  z_25
# 0.117469   z_5

# %%
X_test = z_valid

sample_id = 0
estimator = rfs[0].estimators_[0]

# %%
children_left = estimator.tree_.children_left
children_right = estimator.tree_.children_right

# %%
node_indicator = estimator.decision_path(X_test)
leave_id = estimator.apply(X_test)

feature = estimator.tree_.feature
threshold = estimator.tree_.threshold

sample_id = 0
node_index = node_indicator.indices[node_indicator.indptr[sample_id]:
                                    node_indicator.indptr[sample_id + 1]]

print('Rules used to predict sample %s: ' % sample_id)
for node_id in node_index:
    if leave_id[sample_id] == node_id:
        continue

    if (X_test[sample_id, feature[node_id]] <= threshold[node_id]):
        threshold_sign = "<="
    else:
        threshold_sign = ">"

    print("decision id node %s : (X_test[%s, %s] (= %s) %s %s)"
          % (node_id,
             sample_id,
             feature[node_id],
             X_test[sample_id, feature[node_id]],
             threshold_sign,
             threshold[node_id]))
# Out:
# Rules used to predict sample 0:
# decision id node 0 : (X_test[0, 7] (= -4.7002635) <= -3.9674233198165894)
# decision id node 1 : (X_test[0, 10] (= -4.1538806) <= -3.8830102682113647)
# decision id node 2 : (X_test[0, 4] (= 1.769853) <= 1.8463399410247803)
# decision id node 3 : (X_test[0, 2] (= -4.7491693) <= -4.232415437698364)
# decision id node 4 : (X_test[0, 1] (= 1.9424701) > 1.924157440662384)
# decision id node 56 : (X_test[0, 14] (= 1.2844998) <= 1.400970697402954)
# decision id node 57 : (X_test[0, 13] (= -0.15352787) > -0.5334719717502594)
# decision id node 69 : (X_test[0, 4] (= 1.769853) > 1.5273671746253967)
# decision id node 77 : (X_test[0, 2] (= -4.7491693) <= -4.639214754104614)
# decision id node 78 : (X_test[0, 10] (= -4.1538806) > -4.450443983078003)

# %%
21 % 5
# Out:
# 1

# %%
def plot_node_reconstruction(learn, tree, z_valid,y_valid,node_id = 0,n_imgs = 20):

    idx = (tree.decision_path(z_valid)[:,node_id].toarray() == 1.).reshape(-1)
    
    # We take the mean of the images in the given node
    z = z_valid[idx,:]
    y = y_valid[idx]
    
    values,count = np.unique(y,return_counts=True)
    print(f"Values : {values} with distribution {count}")
    
#     value, count = np.unique(y,return_counts=True)
#     max_count = np.argmax(count)
#     max_label = value[max_count]
    
#     idx = (y == max_label)
    
#     z = z[idx,:]
    
    if not isinstance(z,torch.Tensor):
        z = torch.tensor(z)
    learn.model.cpu()
    with torch.no_grad():
        imgs = learn.decode(z)
    
    n = z.shape[0]
    n_sample = min(n,n_imgs)
    
    idx = np.random.choice(n,n_sample,replace = False)
    
    z = z[idx,:]
    y = y[idx]
    
    img_per_row = 5
    n_rows = n_sample // img_per_row
    if n_sample  % img_per_row != 0:
        n_rows += 1
        
    f, ax = plt.subplots(n_rows,img_per_row,figsize = (20,20))
    
    for i in range(n_rows):
        for j in range(img_per_row):
            img = imgs[i * img_per_row + j].permute(1,2,0).numpy()
            img = np.concatenate([img,img,img],axis = -1)
            ax[i,j].imshow(img)
            ax[i,j].set_title(f"Label : {y[i]}")

# %%
plot_node_reconstruction(learn,estimator,z_valid,y_valid,77)
# Out:
# Values : [4 7 8 9] with distribution [ 59 599   5 407]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from fastai_autoencoder.util import lsuv_init

def find_modules(m, cond):
    if cond(m): return [m]
    return sum([find_modules(o,cond) for o in m.children()], [])

def is_lin_layer(l):
    lin_layers = (nn.Linear)
    return isinstance(l, lin_layers)

layers = find_modules(learn.model, is_lin_layer)
output = lsuv_init(learn.model,x.cuda(),layers=layers)
learn.plot_rec(x)
# Out:
# Freezing all layers
# Unfreezing all layers

# %%
# We load the former model
learn.path = Path()
learn = learn.load(Path("model"))

# %%
learn.fit(1,1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>383.507355</td>
#       <td>360.482971</td>
#       <td>00:51</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Batchnorm without LSUV
learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>152.533173</td>
#       <td>135.702316</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>109.294441</td>
#       <td>93.152649</td>
#       <td>00:51</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>94.334465</td>
#       <td>166.097168</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>81.429611</td>
#       <td>66.828392</td>
#       <td>00:51</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>80.085953</td>
#       <td>144.533447</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>72.479675</td>
#       <td>57.421322</td>
#       <td>00:51</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>72.561394</td>
#       <td>107.953918</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>66.752518</td>
#       <td>52.354488</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>

# %%
# We load the former model
learn.path = Path()
learn.save("model")

# %%
# Batchnorm without LSUV
learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>67.297760</td>
#       <td>92.637917</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>62.453762</td>
#       <td>48.557568</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>65.587029</td>
#       <td>113.099106</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>59.489765</td>
#       <td>46.318256</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>62.109524</td>
#       <td>100.897247</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>58.130547</td>
#       <td>44.578648</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>60.766949</td>
#       <td>144.446915</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>56.150398</td>
#       <td>43.010925</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>

# %%
# We load the former model
learn.path = Path()
learn.save("model")

# %%
learn.load("model")
# Out:
# AutoEncoderLearner(data=ImageDataBunch;
#
# Train: LabelList (48000 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 5,5,5,5,5
# Path: /home/DanyWin/.fastai/data/mnist_png/training;
#
# Valid: LabelList (12000 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 7,1,1,2,2
# Path: /home/DanyWin/.fastai/data/mnist_png/training;
#
# Test: None, model=Sequential(
#   (0): Encoder(
#     (enc_convs): Sequential(
#       (0): MobileConv(
#         (depth_conv): DepthwiseConv(
#           (conv): Conv2d(1, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (point_conv): PointwiseConv(
#           (conv): Conv2d(1, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (1): MobileConv(
#         (depth_conv): DepthwiseConv(
#           (conv): Conv2d(8, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#           (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (point_conv): PointwiseConv(
#           (conv): Conv2d(8, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (2): MobileConv(
#         (depth_conv): DepthwiseConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (point_conv): PointwiseConv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (3): MobileConv(
#         (depth_conv): DepthwiseConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (point_conv): PointwiseConv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#     )
#   )
#   (1): VAEBottleneck(
#     (fc): Sequential(
#       (0): Linear(in_features=1024, out_features=128, bias=True)
#       (1): VAELayer(
#         (blinear): VAELinear(
#           (linear): Linear(in_features=128, out_features=16, bias=True)
#           (mu_linear): Linear(in_features=16, out_features=16, bias=True)
#           (logvar_linear): Linear(in_features=16, out_features=16, bias=True)
#         )
#         (sampler): NormalSampler()
#       )
#     )
#   )
#   (2): Decoder(
#     (dec_convs): Sequential(
#       (0): PointwiseConv(
#         (conv): Conv2d(18, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (1): MobileConv(
#         (depth_conv): DepthwiseConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (point_conv): PointwiseConv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (2): MobileConv(
#         (depth_conv): DepthwiseConv(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (point_conv): PointwiseConv(
#           (conv): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=<bound method AutoEncoderLearner.loss_func of ...>, metrics=[], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[ReplaceTargetCallback
# learn: ...], layer_groups=[Sequential(
#   (0): Conv2d(1, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace)
#   (3): Conv2d(1, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU(inplace)
#   (6): Conv2d(8, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#   (7): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU(inplace)
#   (9): Conv2d(8, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): ReLU(inplace)
#   (12): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#   (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU(inplace)
#   (15): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (16): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (17): ReLU(inplace)
#   (18): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#   (19): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU(inplace)
#   (21): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (22): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (23): ReLU(inplace)
#   (24): Linear(in_features=1024, out_features=128, bias=True)
#   (25): Linear(in_features=128, out_features=16, bias=True)
#   (26): Linear(in_features=16, out_features=16, bias=True)
#   (27): Linear(in_features=16, out_features=16, bias=True)
#   (28): NormalSampler()
#   (29): Conv2d(18, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (30): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (31): ReLU(inplace)
#   (32): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (33): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (34): ReLU(inplace)
#   (35): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (36): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (37): ReLU(inplace)
#   (38): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (39): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (40): ReLU(inplace)
#   (41): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (42): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (43): ReLU(inplace)
# )], add_time=True, silent=False)

# %%
learn.plot_2d_latents()
# Out:
# Computing the TSNE projection

# %%
# Batchnorm without LSUV
learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>57.213802</td>
#       <td>74.782753</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>52.283051</td>
#       <td>40.029442</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>55.669727</td>
#       <td>110.084648</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>51.821789</td>
#       <td>39.593864</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.plot_2d_latents()
# Out:
# Computing the TSNE projection

# %%
learn.path = Path()
learn.save("model")

# %%
# Batchnorm + LSUV Linear
learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])

learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])

learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])

learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])

learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>359.752563</td>
#       <td>341.500824</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>355.527985</td>
#       <td>339.326813</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>313.254883</td>
#       <td>379.046082</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>209.952744</td>
#       <td>192.542297</td>
#       <td>00:53</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>144.043869</td>
#       <td>139.578751</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>105.654976</td>
#       <td>88.906311</td>
#       <td>00:53</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>91.867798</td>
#       <td>88.411674</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>78.289078</td>
#       <td>62.504765</td>
#       <td>00:53</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>74.689232</td>
#       <td>89.515717</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>67.384964</td>
#       <td>51.905613</td>
#       <td>00:53</td>
#     </tr>
#   </tbody>
# </table>

# %%
# LSUV without BN
learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])

learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])

learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])

learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])

learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>505.914124</td>
#       <td>424.364380</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>431.141815</td>
#       <td>406.954834</td>
#       <td>00:46</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>398.508270</td>
#       <td>345.695007</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>94684.343750</td>
#       <td>344.612701</td>
#       <td>00:46</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 00:46<00:46]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>316.774323</td>
#       <td>286.658508</td>
#       <td>00:46</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='375', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/data/anaconda/envs/naox3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-9f432ff4a0b7> in <module>
#       4 learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
#       5
# ----> 6 learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
#       7
#       8 learn.fit_one_cycle(2,1e-3,callbacks=[kl_hook])
#
# /data/anaconda/envs/naox3/lib/python3.7/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      20     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      21                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 22     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      23
#      24 def lr_find(learn:Learner, start_lr:Floats=1e-7, end_lr:Floats=10, num_it:int=100, stop_div:bool=True, wd:float=None):
#
# /data/anaconda/envs/naox3/lib/python3.7/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
#     199         if defaults.extra_callbacks is not None: callbacks += defaults.extra_callbacks
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /data/anaconda/envs/naox3/lib/python3.7/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# /data/anaconda/envs/naox3/lib/python3.7/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      36         if not cb_handler.on_step_end():     opt.zero_grad()
#      37
# ---> 38     return loss.detach().cpu()
#      39
#      40 def get_preds(model:nn.Module, dl:DataLoader, pbar:Optional[PBar]=None, cb_handler:Optional[CallbackHandler]=None,
#
# KeyboardInterrupt:

# %%
learn.path = Path(".")
learn.load("model")
# Out:
# AutoEncoderLearner(data=ImageDataBunch;
#
# Train: LabelList (48000 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 5,5,5,5,5
# Path: /home/DanyWin/.fastai/data/mnist_png/training;
#
# Valid: LabelList (12000 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 7,1,1,2,2
# Path: /home/DanyWin/.fastai/data/mnist_png/training;
#
# Test: None, model=Sequential(
#   (0): Encoder(
#     (enc_convs): Sequential(
#       (0): MobileConv(
#         (depth_conv): DepthwiseConv(
#           (conv): Conv2d(1, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (point_conv): PointwiseConv(
#           (conv): Conv2d(1, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (1): MobileConv(
#         (depth_conv): DepthwiseConv(
#           (conv): Conv2d(8, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#           (bn): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (point_conv): PointwiseConv(
#           (conv): Conv2d(8, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (2): MobileConv(
#         (depth_conv): DepthwiseConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (point_conv): PointwiseConv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (3): MobileConv(
#         (depth_conv): DepthwiseConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (point_conv): PointwiseConv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#     )
#   )
#   (1): VAEBottleneck(
#     (fc): Sequential(
#       (0): Linear(in_features=1024, out_features=128, bias=True)
#       (1): VAELayer(
#         (blinear): VAELinear(
#           (linear): Linear(in_features=128, out_features=16, bias=True)
#           (mu_linear): Linear(in_features=16, out_features=16, bias=True)
#           (logvar_linear): Linear(in_features=16, out_features=16, bias=True)
#         )
#         (sampler): NormalSampler()
#       )
#     )
#   )
#   (2): Decoder(
#     (dec_convs): Sequential(
#       (0): PointwiseConv(
#         (conv): Conv2d(18, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act_fn): ReLU(inplace)
#       )
#       (1): MobileConv(
#         (depth_conv): DepthwiseConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (point_conv): PointwiseConv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#       (2): MobileConv(
#         (depth_conv): DepthwiseConv(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#         (point_conv): PointwiseConv(
#           (conv): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fn): ReLU(inplace)
#         )
#       )
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=<bound method AutoEncoderLearner.loss_func of ...>, metrics=[], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[ReplaceTargetCallback
# learn: ...], layer_groups=[Sequential(
#   (0): Conv2d(1, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace)
#   (3): Conv2d(1, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU(inplace)
#   (6): Conv2d(8, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#   (7): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU(inplace)
#   (9): Conv2d(8, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): ReLU(inplace)
#   (12): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#   (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU(inplace)
#   (15): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (16): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (17): ReLU(inplace)
#   (18): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#   (19): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (20): ReLU(inplace)
#   (21): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (22): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (23): ReLU(inplace)
#   (24): Linear(in_features=1024, out_features=128, bias=True)
#   (25): Linear(in_features=128, out_features=16, bias=True)
#   (26): Linear(in_features=16, out_features=16, bias=True)
#   (27): Linear(in_features=16, out_features=16, bias=True)
#   (28): NormalSampler()
#   (29): Conv2d(18, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (30): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (31): ReLU(inplace)
#   (32): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (33): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (34): ReLU(inplace)
#   (35): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (36): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (37): ReLU(inplace)
#   (38): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#   (39): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (40): ReLU(inplace)
#   (41): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (42): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (43): ReLU(inplace)
# )], add_time=True, silent=False)

# %%
learn.plot_rec()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
learn.plot_shades()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-9-deb7f3e04450> in <module>
# ----> 1 learn.plot_shades()
#
# /data/home/DanyWin/fastai-autoencoder/fastai_autoencoder/learn.py in plot_shades(self, x, i, n_perturb, mag_perturb, ax)
#      87         """Plot the reconstruction of the """
#      88         if not ax:
# ---> 89             fig, ax = plt.subplots(n_z,n_perturb, figsize=(16,12))
#      90             fig.tight_layout()
#      91
#
# UnboundLocalError: local variable 'n_z' referenced before assignment

# %%
learn.plot_2d_latents(n_batch=20)
# Out:
# Computing the TSNE projection

# %%
output = learn.get_error()

# %%
data = loss_func(x,x_rec).numpy()

# %%
alpha = np.percentile(data,95)

# %%
mask = (data > alpha)

# %%
values = learn.data.valid_ds.y.items[idx].reshape(-1)

# %%
pd.value_counts(values)
# Out:
# 8    160
# 2    151
# 4     60
# 5     51
# 3     48
# 6     46
# 0     32
# 7     26
# 9     24
# 1      2
# dtype: int64

# %%
idx = np.argwhere(np.asarray(mask))
outliers = x[idx]

# %%
def plot_img(x,x_rec,i):
    img = x[i].squeeze(0).permute(1,2,0).numpy()
    img = np.concatenate([img,img,img], axis = -1)
    
    img_rec = x_rec[i].squeeze(0).permute(1,2,0).numpy()
    img_rec = np.concatenate([img_rec,img_rec,img_rec], axis = -1)
    
    fig,ax = plt.subplots(2,figsize = (16,8))
    ax[0].imshow(img)
    ax[0].set_title("Original")
    
    ax[1].imshow(img_rec)
    ax[1].set_title("Reconstruction")

# %%
o, o_rec = x[idx], x_rec[idx]

# %%
plot_img(o,o_rec,25)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plot_img(outliers,0)

# %%
plt.hist(data,bins = 20)
# Out:
# (array([9.780e+02, 1.386e+03, 2.149e+03, 2.220e+03, 1.858e+03, 1.309e+03, 8.390e+02, 5.040e+02, 3.010e+02, 1.870e+02,
#         1.070e+02, 6.300e+01, 3.800e+01, 2.200e+01, 1.300e+01, 1.100e+01, 8.000e+00, 5.000e+00, 0.000e+00, 2.000e+00]),
#  array([  3.559248,  10.69776 ,  17.836271,  24.974783,  32.113297,  39.25181 ,  46.39032 ,  53.52883 ,  60.667343,
#          67.805855,  74.94437 ,  82.08288 ,  89.22139 ,  96.3599  , 103.49841 , 110.636925, 117.77544 , 124.91395 ,
#         132.05246 , 139.19096 , 146.32948 ], dtype=float32),
#  <a list of 20 Patch objects>)

# %%
loss_func = lambda x,x_rec : F.mse_loss(x, x_rec, reduction='none').view(x.shape[0], -1).sum(dim=-1)

# %%
t = x[0].permute(1,2,0).numpy()).float

# %%
t = np.concatenate([t,t,t],axis = -1)

# %%
data.valid_ds.x[2]
# Out:
# Image (3, 28, 28)

# %%
plt.imshow(t)

# %%
t = torch.load("encoder.pth")

# %%
t
# Out:
# Sequential(
#   (0): Encoder(
#     (enc_convs): Sequential(
#       (0): Sequential(
#         (0): Sequential(
#           (0): Conv2d(1, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#         )
#         (1): Sequential(
#           (0): Conv2d(1, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#         )
#       )
#       (1): Sequential(
#         (0): Sequential(
#           (0): Conv2d(8, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8, bias=False)
#           (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#         )
#         (1): Sequential(
#           (0): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#         )
#       )
#       (2): Sequential(
#         (0): Sequential(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#         )
#         (1): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#         )
#       )
#       (3): Sequential(
#         (0): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#         )
#         (1): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#         )
#       )
#     )
#   )
#   (1): VAEBottleneck(
#     (fc): Sequential(
#       (0): Linear(in_features=1024, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#       (2): BayesianLayer(
#         (blinear): BayesianLinear(
#           (linear): Linear(in_features=128, out_features=10, bias=True)
#           (mu_linear): Linear(in_features=10, out_features=10, bias=True)
#           (logvar_linear): Linear(in_features=10, out_features=10, bias=True)
#         )
#         (sampler): NormalSampler()
#       )
#     )
#   )
# )

# %%
path = untar_data(URLs.MNIST)
bs = 128
tfms = get_transforms(do_flip = False)

size = 64

data = (ImageList.from_folder(path/"training")
        .split_by_rand_pct(seed=42)
        .label_from_folder()
        .transform(tfms,size = size)
        .databunch(bs = bs))

def get_one_channel(batch):
    x,y = batch
    return x[:,0,:,:].unsqueeze(1),y
get_one_channel._order = 99

data.add_tfm(get_one_channel)

# %%
learn.data = data

# %%
x,y = learn.get_latents(ds_type=DatasetType.Train,n_batch=20)

# %%
x,y = x.numpy(),y.numpy()

# %%
from sklearn.ensemble import RandomForestClassifier

criterion = "entropy"

clf = RandomForestClassifier(n_estimators=100,max_depth=10,random_state=42,
                            n_jobs=-1)

clf.fit(x,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
y_pred = clf.predict(x)
(y_pred == y).mean()
# Out:
# 0.9984375

# %%
x_val,y_val = learn.get_latents(ds_type=DatasetType.Valid)
x_val,y_val = x_val.numpy(),y_val.numpy()

# %%
y_pred = clf.predict(x_val)
(y_pred == y_val).mean()
# Out:
# 0.8984166666666666
